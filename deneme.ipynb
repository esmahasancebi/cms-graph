# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cms=pd.read_csv('cmsopendata.csv') 
cms
# Out:
#           Run      Event Type1         E1        px1        py1        pz1  \
# 0      165617   75206813     G   10.16230   0.476262  -8.516420    5.52306
# 1      165617   75678475     G   15.87990  15.061800  -1.665810   -4.74643
# 2      165617   74428554     G   21.82790  -6.221380  11.084500   17.74470
# 3      165617   75193169     G   19.49230   2.761250  -5.576860  -18.47190
# 4      165617   74832715     G    8.09718   4.612670  -1.838860    6.39492
# 5      165617   74981507     G   30.58620  15.521800   5.129310  -25.85090
# 6      165617   75612982     G    7.55441   1.291290  -5.358840   -5.16462
# 7      165617   74760204     G   24.63760   9.983590  19.142600  -11.86970
# 8      165617   75017052     G   22.50570   5.629630  -9.949660   19.38570
# 9      165617   75204668     G   10.70510  -8.466430  -2.237440   -6.15638
# 10     165617   75056096     G    6.03714   1.169260  -3.401750   -4.84735
# ...

# %%
print(cms.shape)
# Out:
# (31892, 21)

# %%
cms['Type2'].value_counts()
# Out:
# G    26025
# T     5867
# Name: Type2, dtype: int64

# %%
cms['Type1'].value_counts()
# Out:
# G    31892
# Name: Type1, dtype: int64

# %%
cms['Q2'].value_counts()
# Out:
# -1    18573
#  1    13319
# Name: Q2, dtype: int64

# %%
sns.lmplot(x='px1' , y= 'E1' , data =cms )
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x='py1' , y= 'E1' , data =cms )
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x='pz1' , y= 'E1' , data =cms )
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(y='px1' , x= 'pt1' , data =cms )
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(y='py1' , x ='pt1' , data =cms )
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(y='pz1' , x= 'pt1' , data =cms )
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(y='pt1' , x= 'eta1' , data =cms )
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(y='eta1' , x= 'phi1' , data =cms )
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(cms)
sns.plt.show()

# %%
masses = cms.M # assigning mass values to a variable 'mass'

# bins from 2.0 to 5.0 in 0.10 intervals
hist = masses.hist(bins=[2.0, 2.10, 2.20, 2.30, 2.40, 2.50, 2.60, 2.70, 2.80, 2.90, 3.0, 3.10, 3.20, 3.30, 3.40, 3.50, 3.60, 3.70, 3.80, 3.90, 4.0, 4.10, 4.20, 4.30, 4.40, 4.50, 4.60, 4.70, 4.80, 4.90, 5.0])
plt.title('The histogram of the invariant masses of two muons \n')
plt.xlabel("Invariant Masses in GeV")
plt.ylabel("Frequency")
plt.show()

# %%
mean_masses = np.mean(masses)
print(mean_masses) 

variance_masses = np.var(masses)
print(variance_masses)
# Out:
# 3.084373634453779
# 0.39216919088955843

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(cms, alpha=0.2, figsize=(6, 6), diagonal='kde')
